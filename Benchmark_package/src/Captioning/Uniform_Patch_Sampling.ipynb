# %%
import os
import json
import random
import csv

WSI_id_name = {
    "FFHO026": "transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome.tif",
    "FFMB028": "transfered_Xenium_Prime_Mouse_Brain_Coronal_FF_he_image.ome.tif",
    "WMPW025": "transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome.tif",
    "FFMC016": "transfered_Xenium_V1_mouse_Colon_FF_he_image.ome.tif",
    "WMPP017": "transfered_Xenium_V1_mouse_pup_he_image.ome.tif",
    "PDHP030": "transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome.tif",
    "PDHS029": "transfered_Xenium_Prime_Human_Skin_FFPE_he_image.ome.tif",
    "HHDX011": "transfered_Xenium_V1_hHeart_nondiseased_section_FFPE_he_image.ome.tif",
    "HPXM007": "transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome.tif",
    "HSDX009": "transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome.tif",
}

def greedy_sample_patches(json_files, patches_per_cluster=5, total_patches_per_wsi=100, output_csv="greedy_sampled_patches.csv"):
    all_samples = []

    for json_path in json_files:
        wsi_id = os.path.splitext(os.path.basename(json_path))[0].replace("cluster_to_patch_ids_", "")

        if wsi_id not in WSI_id_name:
            print(f"[SKIPPED] Unknown WSI ID: {wsi_id}")
            continue

        wsi_name = os.path.splitext(WSI_id_name[wsi_id])[0]

        with open(json_path, 'r') as f:
            cluster_map = json.load(f)

        sorted_clusters = sorted(cluster_map.items(), key=lambda item: len(item[1]), reverse=True)
        patches_collected = 0
        sampled_for_this_wsi = []
        used_patches = set()

        # First pass: up to 5 patches per cluster
        for cluster_id, patch_list in sorted_clusters:
            if patches_collected >= total_patches_per_wsi:
                break

            unused = [p for p in patch_list if p not in used_patches]
            if not unused:
                continue

            to_sample = min(patches_per_cluster, len(unused), total_patches_per_wsi - patches_collected)
            selected = random.sample(unused, to_sample)

            for patch in selected:
                sampled_for_this_wsi.append({
                    "wsi_name": wsi_name,
                    "patch_filename": patch
                })
                used_patches.add(patch)

            patches_collected += to_sample

        # Second pass: fill remaining up to 100
        if patches_collected < total_patches_per_wsi:
            for cluster_id, patch_list in sorted_clusters:
                if patches_collected >= total_patches_per_wsi:
                    break

                unused = [p for p in patch_list if p not in used_patches]
                while unused and patches_collected < total_patches_per_wsi:
                    patch = unused.pop()
                    sampled_for_this_wsi.append({
                        "wsi_name": wsi_name,
                        "patch_filename": patch
                    })
                    used_patches.add(patch)
                    patches_collected += 1

        if patches_collected < total_patches_per_wsi:
            print(f"[WARNING] {wsi_id}: Only collected {patches_collected} patches (needed 100)")

        all_samples.extend(sampled_for_this_wsi)

    # Save to CSV
    os.makedirs(os.path.dirname(output_csv) or ".", exist_ok=True)
    with open(output_csv, 'w', newline='') as csvfile:
        fieldnames = ['wsi_name', 'patch_filename']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(all_samples)

    print(f"[DONE] Saved {len(all_samples)} patch samples across all WSIs to {output_csv}")
    return all_samples

# %%
json_files = [
    "cluster_to_patch_ids_FFHO026.json",
    "cluster_to_patch_ids_FFMB028.json",
    "cluster_to_patch_ids_FFMC016.json",
    "cluster_to_patch_ids_HHDX011.json",
    "cluster_to_patch_ids_HPXM007.json",
    "cluster_to_patch_ids_HSDX009.json",
    "cluster_to_patch_ids_PDHP030.json",
    "cluster_to_patch_ids_PDHS029.json",
    "cluster_to_patch_ids_WMPP017.json",
    "cluster_to_patch_ids_WMPW025.json",
]

greedy_sample_patches(json_files, output_csv="sampled_patches.csv")
# Out:
# [WARNING] FFMB028: Only collected 0 patches (needed 100)
# [WARNING] HHDX011: Only collected 0 patches (needed 100)
# [DONE] Saved 800 patch samples across all WSIs to sampled_patches.csv
# [{'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_3389.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4521.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_3437.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_3438.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_2610.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_6294.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_6853.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_5170.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_8092.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_7136.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_2636.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_3412.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_2642.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_3695.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_3200.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_7934.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_8099.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_6692.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_6862.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_7937.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4416.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_5196.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_2336.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4369.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_5081.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_6468.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_6142.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_6473.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_6199.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_5460.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_3758.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4149.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_5207.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4145.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_2514.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_5459.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_5074.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_5572.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4389.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_5733.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_3966.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_5085.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4078.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_3460.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4691.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_2709.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_3544.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_2592.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4613.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_3548.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4690.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4816.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4904.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_5199.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4689.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4997.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4715.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4712.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4823.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4546.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_3430.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_3542.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_3940.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_3711.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4384.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_2889.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_2614.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_2439.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_2443.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_2229.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_3142.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_3863.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_3590.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4095.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_5222.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4538.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4929.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_5208.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4812.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4365.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4118.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4061.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4066.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4063.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4117.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_6680.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_6681.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_6968.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_7916.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_6808.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_2492.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_2434.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_2490.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_2493.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_2883.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4500.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_5908.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_4951.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_5458.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Ovary_FF_he_image.ome',
#   'patch_filename': 'patch_6119.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1380.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1512.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_644.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_922.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_777.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1629.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1244.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1513.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1785.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1435.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1295.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1258.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_919.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_913.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_882.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_492.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_726.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_491.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_530.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_529.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1950.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_892.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_928.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_807.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_704.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_977.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_866.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_750.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1363.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1670.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1308.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_2109.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1613.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_619.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_2128.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1173.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1283.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1291.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1216.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1136.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1315.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_968.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1073.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1196.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1351.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_2014.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_2079.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_2041.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_2042.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_2038.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_765.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_876.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_842.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_767.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1144.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1966.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1891.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1198.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1275.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_2118.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_638.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_679.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_531.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_640.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_639.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_2069.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_2073.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_2068.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1872.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_2036.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1913.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_2062.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1726.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1949.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1912.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_859.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_858.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_820.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_821.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1992.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1993.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_2030.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_2031.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1254.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1058.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1186.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1445.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1183.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1221.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1146.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1296.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_656.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_618.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_694.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_852.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1004.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_967.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1234.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1270.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_Colon_FF_he_image.ome',
#   'patch_filename': 'patch_1233.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_764.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_329.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_302.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_687.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_366.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_432.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_394.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_476.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_427.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_252.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_915.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_783.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_771.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_698.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_881.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_510.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_810.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_632.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_552.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_560.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_575.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_458.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_571.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_758.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_494.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_868.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_875.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_832.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_686.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_833.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_646.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_865.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_790.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_609.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_753.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_895.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_850.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_848.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_778.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_859.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_454.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_417.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_678.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_413.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_674.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_227.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_334.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_409.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_253.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_259.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_275.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_352.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_356.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_235.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_284.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_598.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_414.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_373.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_332.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_747.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_695.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_878.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_726.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_733.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_730.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_488.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_490.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_451.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_416.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_453.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_860.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_932.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_900.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_937.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_826.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_387.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_535.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_383.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_423.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_346.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_652.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_653.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_617.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_654.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_690.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_847.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_841.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_846.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_880.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_884.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_885.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_927.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_928.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_925.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_922.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_642.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_643.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_610.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_683.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_human_Pancreas_FFPE_he_image.ome',
#   'patch_filename': 'patch_904.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2427.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2525.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2890.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_3005.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1535.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_3185.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_3263.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2997.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_3006.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2999.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1230.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1134.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1222.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1523.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_902.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2436.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2490.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_3094.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_3365.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1745.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1051.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1496.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1565.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_937.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_931.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_979.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1344.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_736.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_917.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1326.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1207.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_839.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_702.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1014.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_769.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2385.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1771.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2284.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2082.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2216.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1166.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1778.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_783.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_726.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1526.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_3416.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2031.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_3080.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2581.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2336.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2307.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2434.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2308.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2247.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2555.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1199.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1508.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1517.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1389.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1448.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_3074.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2691.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2628.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2882.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2688.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1801.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1485.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1436.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1314.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_985.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2560.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2432.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2369.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2306.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2312.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_3424.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2340.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_3421.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_3218.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2605.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2570.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2266.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2758.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2947.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2692.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1341.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1107.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1095.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1037.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_1226.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2601.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_3167.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_2861.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_3420.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_3349.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_3239.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_3240.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_3304.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_3363.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_hSkin_nondiseased_section_1_FFPE_he_image.ome',
#   'patch_filename': 'patch_3177.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_1465.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_1349.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_805.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_1095.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_2120.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_2936.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_2650.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_2641.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_2449.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_2601.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_2134.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_1807.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_1829.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_937.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_1330.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_2616.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_2723.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_2786.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_2199.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_2247.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_623.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_1164.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_1022.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_1158.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_702.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_1058.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_1932.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_1336.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
#   'patch_filename': 'patch_1877.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Human_Prostate_FFPE_he_image.ome',
# ...
#   'patch_filename': 'patch_9344.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_10007.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_5811.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_5211.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_4879.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_4612.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_4611.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_7690.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_9896.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_10037.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_10046.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_10053.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_7956.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_9842.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_8289.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_7824.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_8022.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_5338.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_4738.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_4739.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_5073.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_5339.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_6386.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_6724.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_6588.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_6993.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_6858.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_4274.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_4139.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_4407.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_4399.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_4271.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_3212.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_4085.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_3213.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_2879.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_3012.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_5820.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_5819.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_7358.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_5941.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_5341.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_4080.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_3946.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_4146.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_4078.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_4145.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_10035.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_9702.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_9901.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_9839.tif'},
#  {'wsi_name': 'transfered_Xenium_V1_mouse_pup_he_image.ome',
#   'patch_filename': 'patch_9904.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_6422.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_6832.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_6498.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_8786.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_8621.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_10818.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_12347.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_13544.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_11281.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_10065.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_9921.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_6528.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_9447.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_6616.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_5425.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_8493.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_6527.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_7970.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_8400.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_7455.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_9880.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_10106.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_9455.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_9702.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_9444.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_12971.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_13792.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_12532.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_13970.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_13459.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_12517.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_13965.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_13294.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_12774.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_13115.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_11444.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_11617.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_11451.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_10342.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_11533.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_10477.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_9300.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_10056.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_10651.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_11084.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_5471.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_6064.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_8115.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_8505.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_5820.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_4882.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_4977.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_5220.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_5136.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_4979.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_4751.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_4820.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_4312.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_6347.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_4827.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_5502.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_3770.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_5491.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_3951.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_3618.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_10288.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_10712.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_10625.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_10282.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_10627.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_8826.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_8226.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_7794.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_7372.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_8049.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_11005.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_11705.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_12714.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_8886.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_12124.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_6767.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_10497.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_10756.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_9824.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_13732.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_8627.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_6412.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_6499.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_7756.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_5718.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_8905.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_8687.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_10374.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_9252.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_8856.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_11363.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_12973.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_10161.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_10248.tif'},
#  {'wsi_name': 'transfered_Xenium_Prime_Mouse_Pup_FFPE_he_image.ome',
#   'patch_filename': 'patch_10258.tif'}]
